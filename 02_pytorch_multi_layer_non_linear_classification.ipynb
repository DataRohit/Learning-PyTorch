# %% [markdown]
# # **PyTorch Neural Network Classification**

# %% [markdown]
# **Types Of Classification:**
#  - **Binary Classification**
#  - **Multi-Class Classification**
#  - **Multi-Label Classification**

# %% [markdown]
# **Topics to Cover:**
#  - **Architecture of a Classification Neural Network**
#  - **Classification Data**
#  - **Building Classification Model**
#  - **Fitting the Model**
#  - **Making Predictions & Evaluation**
#  - **Improving the Model**
#  - **Non-Linearity**
#  - **Replicating Non-Linear Functions**

# %% [markdown]
# ## **Device Agnostic Setting**

# %%
# Imports
import torch

# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## **Architecture of a Classification Neural Network**

# %% [markdown]
# **Component of Model:**
#  - **Input Layer**
#  - **Hidden Layer(s)**
#  - **Neurons per Hidden Layer**
#  - **Output Layer Shape**
#  - **Hidden Layer Activation**
#  - **Output Activation**
#  - **Loss Function**
#  - **Optimizer**

# %% [markdown]
# ## **Generate Classification Data**

# %%
# Import from sklearn to generate classification data
from sklearn.datasets import make_circles

# Initialize the required number of samples
n_samples = 20_000

# Generate the data
X, y = make_circles(n_samples = n_samples, noise = 0.05, random_state = 42, factor = 0.6)

# %%
# First 5 features
print(f"First 5 Features:\n{X[:5]}")

# First 5 labels
print(f"\nFirst 5 Labels:\n{y[:5]}")
# Out:
# First 5 Features:
# [[ 0.54191946  0.18251496]
#  [ 0.26400601  0.95066635]
#  [ 0.60382298 -0.68823723]
#  [ 0.79333075  0.59174747]
#  [-0.55174896  0.41776573]]
#
# First 5 Labels:
# [1 0 0 0 1]

# %%
# Import pandas and numpy
import pandas as pd
import numpy as np

# Add the data into pandas dataframe
df = pd.DataFrame({
    "X1": X[:, 0],
    "X2": X[:, 1],
    "y": y
})

# View the head data
df.head()
# Out:
#          X1        X2  y
# 0  0.541919  0.182515  1
# 1  0.264006  0.950666  0
# 2  0.603823 -0.688237  0
# 3  0.793331  0.591747  0
# 4 -0.551749  0.417766  1

# %%
# Value count the target
df["y"].value_counts()
# Out:
# 1    10000
# 0    10000
# Name: y, dtype: int64

# %%
# Import matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# Plot the classification data
plt.scatter(
    x = df["X1"],
    y = df["X2"],
    c = df["y"],
    cmap = plt.cm.RdYlBu
)
plt.show()

# %% [markdown]
# ### **Input and Output Shapes**

# %%
# Check the shapes of out features and labels
X.shape, y.shape
# Out:
# ((20000, 2), (20000,))

# %% [markdown]
# ### **Train Test Split**

# %%
# Import train_test_split() from sklearn
from sklearn.model_selection import train_test_split

# Make training and testing data from the complete data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size = 0.8, shuffle = True, random_state = 42
)

# Print the shape of the data
X_train.shape, X_test.shape, y_train.shape, y_test.shape#
# Out:
# ((16000, 2), (4000, 2), (16000,), (4000,))

# %%
# Convert data to tensor
X_train = torch.from_numpy(X_train).type(torch.float32)
y_train = torch.from_numpy(y_train).type(torch.float32)

X_test = torch.from_numpy(X_test).type(torch.float32)
y_test = torch.from_numpy(y_test).type(torch.float32)

# %%
# View the first five samples
X[:5], y[:5]
# Out:
# (array([[ 0.54191946,  0.18251496],
#         [ 0.26400601,  0.95066635],
#         [ 0.60382298, -0.68823723],
#         [ 0.79333075,  0.59174747],
#         [-0.55174896,  0.41776573]]),
#  array([1, 0, 0, 0, 1]))

# %% [markdown]
# ## **Building Classification Model**

# %%
# PyTorch import for neural networks
from torch import nn

# %%
# Construct the classification model
class MultiLayerNonLinearClassification(nn.Module):
    def __init__(self):
        super().__init__()

        # Add layers to our neural network
        self.layer_1 = nn.Linear(in_features = 2, out_features = 10)
        self.layer_2 = nn.Linear(in_features = 10, out_features = 5)
        self.layer_3 = nn.Linear(in_features = 5, out_features = 1)

        # Activation function
        self.relu = nn.ReLU()

    # forward() method computation
    def forward(self, x):
        # Return the output from the last layer
        return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))

# %%
# Move the model to device
mlnl_model = MultiLayerNonLinearClassification().to(device)

# %% [markdown]
# ### **Setup Loss Function, Optimizer and Performance Metrics**

# %%
# Loss function
loss_fn = nn.BCEWithLogitsLoss() # This loss function has built-in sigmoid layer

# Optimizer
optimizer = torch.optim.SGD(params = mlnl_model.parameters(), lr = 1e-1)

# %%
# Calculate accuracy
def accuracy_fn(y_true, y_pred):
    # Get the count of correct predictions
    correct_count = torch.eq(y_true, y_pred).sum().item()

    # Calculate the accuracy
    acc = (correct_count / len(y_pred)) * 100

    # Return the accuracy
    return acc

# %% [markdown]
# ## **Train Model**

# %% [markdown]
# ### **Move Data to Device**

# %%
# Move the data to device
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %% [markdown]
# ### **Before Training**

# %%
# View output of forward pass on the test data (Before training)
y_logits = mlnl_model(X_test)
y_logits[:5]
# Out:
# tensor([[0.1925],
#         [0.1945],
#         [0.1909],
#         [0.1945],
#         [0.1935]], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
# Use sigmoid to model logits (Probability)
y_pred_probs = torch.sigmoid(y_logits)
y_pred_probs[:5]
# Out:
# tensor([[0.5480],
#         [0.5485],
#         [0.5476],
#         [0.5485],
#         [0.5482]], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
# Round the propabilities
y_preds = torch.round(y_pred_probs)
y_preds[:5]
# Out:
# tensor([[1.],
#         [1.],
#         [1.],
#         [1.],
#         [1.]], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
# All above code in one line
y_pred_labels = torch.round(torch.sigmoid(mlnl_model(X_test.to(device))))
y_pred_labels[:5]
# Out:
# tensor([[1.],
#         [1.],
#         [1.],
#         [1.],
#         [1.]], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
# Check for equality
print(torch.eq(y_preds.squeeze(), y_pred_labels.squeeze()))

# Get rid of extra dimension
print(y_preds.squeeze())
# Out:
# tensor([True, True, True,  ..., True, True, True], device='cuda:0')
# tensor([1., 1., 1.,  ..., 1., 1., 1.], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)

# %% [markdown]
# ### **Training and Testing Loops**

# %%
# Import accuracy score
from sklearn.metrics import accuracy_score

# Set manual seed for reproducible outputs
torch.manual_seed(42)

# Set the number of epochs
epochs = 1_000

# Setup empty lists to track model progress
train_loss_values = []
test_loss_values = []
epoch_count = []

# Building the training and testing loop
for epoch in range(epochs):
    # Set the model in training mode
    mlnl_model.train()

    # Forward pass - Get the predictions
    y_train_logits = mlnl_model(X_train).squeeze()
    y_train_pred = torch.round(torch.sigmoid(y_train_logits))

    # Calculate the loss and accuracy
    train_loss = loss_fn(y_train_logits, y_train)
    train_accuracy = accuracy_fn(y_train, y_train_pred)

    # Optimizer zero grad
    optimizer.zero_grad()

    # Backpropogation
    train_loss.backward()

    # Update the optimizer
    optimizer.step()

    # Set the model into testing mode
    mlnl_model.eval()

    # Enable the inference mode for faster predictions
    with torch.inference_mode():
        # Forward pass - Get the predictions
        y_test_logits = mlnl_model(X_test).squeeze()
        y_test_pred = torch.round(torch.sigmoid(y_test_logits))

        # Calculate the loss and accuracy
        test_loss = loss_fn(y_test_logits, y_test)
        test_accuracy = accuracy_fn(y_test, y_test_pred)

    # For every epochs track the progress
    if epoch % (epochs // 10) == 0:
        ## Update the lists
        epoch_count.append(epoch)
        train_loss_values.append(train_loss.detach().to("cpu").numpy())
        test_loss_values.append(test_loss.detach().to("cpu").numpy())

        ## Print the progress
        print(f"Epoch: {epoch}\t| Train Loss: {train_loss:.4f} | Train Accuracy: {train_accuracy:.4f} | Test Loss: {test_loss:.4f} | Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch: 0	| Train Loss: 0.6956 | Train Accuracy: 50.3438 | Test Loss: 0.6987 | Test Accuracy: 48.6250
# Epoch: 100	| Train Loss: 0.6871 | Train Accuracy: 58.5375 | Test Loss: 0.6876 | Test Accuracy: 57.4250
# Epoch: 200	| Train Loss: 0.6771 | Train Accuracy: 54.9000 | Test Loss: 0.6779 | Test Accuracy: 53.8250
# Epoch: 300	| Train Loss: 0.6621 | Train Accuracy: 56.5938 | Test Loss: 0.6634 | Test Accuracy: 55.9000
# Epoch: 400	| Train Loss: 0.6293 | Train Accuracy: 75.7875 | Test Loss: 0.6304 | Test Accuracy: 75.5500
# Epoch: 500	| Train Loss: 0.5486 | Train Accuracy: 87.5938 | Test Loss: 0.5483 | Test Accuracy: 87.6000
# Epoch: 600	| Train Loss: 0.3693 | Train Accuracy: 99.7000 | Test Loss: 0.3670 | Test Accuracy: 99.8250
# Epoch: 700	| Train Loss: 0.2082 | Train Accuracy: 99.9188 | Test Loss: 0.2063 | Test Accuracy: 99.9250
# Epoch: 800	| Train Loss: 0.1265 | Train Accuracy: 99.9625 | Test Loss: 0.1252 | Test Accuracy: 100.0000
# Epoch: 900	| Train Loss: 0.0862 | Train Accuracy: 99.9625 | Test Loss: 0.0851 | Test Accuracy: 100.0000

# %% [markdown]
# ### **Plot Loss Curves**

# %%
# Plot loss curves
plt.figure(figsize = (8, 5))
plt.plot(epoch_count, train_loss_values, label = "Train Loss", marker = "o")
plt.plot(epoch_count, test_loss_values, label = "Test Loss", marker = "o")
plt.title("Training and Testing Loss Curves")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## **Making Predictions**

# %% [markdown]
# ### **Download File and Load Helper Functions**

# %%
import requests
from pathlib import Path

# Download helper functions from Learn PyTorch repo (if not already downloaded)
if Path("helper_functions.py").is_file():
  print("helper_functions.py already exists, skipping download")
else:
  print("Downloading helper_functions.py")
  request = requests.get("https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/helper_functions.py")
  with open("helper_functions.py", "wb") as f:
    f.write(request.content)

from helper_functions import plot_predictions, plot_decision_boundary
# Out:
# helper_functions.py already exists, skipping download

# %%
# Plot decision boundaries for training and test sets
plt.figure(figsize=(16, 5))

plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(mlnl_model, X_train, y_train)

plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(mlnl_model, X_test, y_test)

plt.show()

# %% [markdown]
# ### **Plot Classification Report**

# %%
# Import classification report from sklearn
from sklearn.metrics import classification_report

# Use the inference mode
with torch.inference_mode():
    # Get the outputs
    y_test_pred = torch.round(torch.sigmoid(mlnl_model.to(device)(X_test)))

    # Print the classification report
    print(classification_report(y_test.to("cpu"), y_test_pred.to("cpu")))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2055
#          1.0       1.00      1.00      1.00      1945
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000

# %% [markdown]
# ### **Save Model**

# %%
# Mount google drive
from google.colab import drive
drive.mount("./Drive", force_remount = True)
# Out:
# Mounted at ./Drive

# %%
# Create models directory
MODEL_PATH = Path("./Drive/MyDrive/PyTorch Course/models")
MODEL_PATH.mkdir(parents = True, exist_ok = True)

# Create model save path
MODEL_NAME = "02_pytorch_multi_layer_non_linear_classification.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# Save the model state dict
print(f"Saving Model to: {MODEL_SAVE_PATH}")
torch.save(obj = mlnl_model.state_dict(), f = MODEL_SAVE_PATH)
# Out:
# Saving Model to: Drive/MyDrive/PyTorch Course/models/02_pytorch_multi_layer_non_linear_classification.pth

# %%
# Check the saved file path
# !ls -l "./Drive/MyDrive/PyTorch Course/models/02_pytorch_multi_layer_non_linear_classification.pth"
# Out:
# -rw------- 1 root root 3039 Jul 18 15:08 './Drive/MyDrive/PyTorch Course/models/02_pytorch_multi_layer_non_linear_classification.pth'

# %% [markdown]
# ## **Loading a Model**

# %% [markdown]
# ### **Initialize Model**

# %%
# Instantiate a new instance of our model (this will be instantiated with random weights)
loaded_mlnl_model = MultiLayerNonLinearClassification().to(device)

# Load the state_dict of our saved model (this will update the new instance of our model with trained weights)
loaded_mlnl_model.load_state_dict(torch.load(f = MODEL_SAVE_PATH))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### **Generate Outputs**

# %%
# Put the loaded model into evaluation mode
loaded_mlnl_model.eval()

# Use the inference mode context manager to make predictions
with torch.inference_mode():
    loaded_model_y_test_pred = torch.round(torch.sigmoid(loaded_mlnl_model(X_test)))

# %% [markdown]
# ### **Print Classification Report**

# %%
# Print the classification report
print(classification_report(y_test.to("cpu"), loaded_model_y_test_pred.to("cpu")))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2055
#          1.0       1.00      1.00      1.00      1945
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
